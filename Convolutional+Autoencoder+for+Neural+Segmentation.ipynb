# %% [markdown]
# # Convolutional Autoencoder for Neural Segmentation
#
# This is my implementation for the ISBI Challenge: Segmentation of neuronal structures in EM stacks. This is a challenge which can be found on the website of Dr. Seung's Lab at Princton http://seunglab.org/ or directly at http://brainiac2.mit.edu/isbi_challenge/ .
#
# ## The Challenge
#
# I will provide some information from the website about the challenge directly in this notebook. Please feel free to only read what seems important to you.
#
# ### Background and set-up
# In this challenge, a full stack of EM slices will be used to train machine learning algorithms for the purpose of automatic segmentation of neural structures. The images are representative of actual images in the real-world, containing some noise and small image alignment errors. None of these problems led to any difficulties in the manual labeling of each element in the image stack by an expert human neuroanatomist. The aim of the challenge is to compare and rank the different competing methods based on their pixel and object classification accuracy.
#
# ### Training data
# Training dataInput training data and corresponding labels.
# The training data is a set of 30 sections from a serial section Transmission Electron Microscopy (ssTEM) data set of the Drosophila first instar larva ventral nerve cord (VNC). The microcube measures 2 x 2 x 1.5 microns approx., with a resolution of 4x4x50 nm/pixel.
#
# The corresponding binary labels are provided in an in-out fashion, i.e. white for the pixels of segmented objects and black for the rest of pixels (which correspond mostly to membranes).
#
# To get the training data, please, register, log in and go to the "Downloads" section.
#
# This is the only data that participants are allowed to use to train their algorithms.
#
# ### Test data
# The contesting segmentation methods will be ranked by their performance on a test dataset, also available under "downloads", after registration. This test data is another volume from the same Drosophila first instar larva VNC as the training dataset.
#
# ### Results format
# The results are expected to be submitted as a 32-bit TIFF 3D image, which values between 0 (100% membrane certainty) and 1 (100% non-membrane certainty).

# %% [markdown]
# ## Data Preprocessing
#
# The data is read from three different .tif files and stored as numpy arrays. I needed to do some preprocessing before passing them to tensorflow. In particular, I've normalized the data, put it in batches and reshaped it so it could be passed to tensorflow.

# %%
# Import dependencies
from skimage import io
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
import numpy as np

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %%
# Load data
train_volume = io.imread('Data/train-volume.tif')
train_labels = io.imread('Data/train-labels.tif')
test_volume = io.imread('Data/test-volume.tif')

# %%
# Normalize function
def normalize(x):
    x = x.astype(np.float32)
    x /=255
    return x

# %%
# Normalize data
train_volume = normalize(train_volume)
train_labels = normalize(train_labels)
test_volume = normalize(test_volume)

# %%
# Batch function

# The data is currently a multidimensional numpy array (ndarray) with 3 dimensions. It has the shape 30 * 512 * 512, which
# means that the data exists of 30 greyscale pictures with dimension 512 pixels on 512 pixels. We want to make 30 batches of 1 
# picture each. We'll also have to reshape the data to pass it to convolutional layers in tensorflow (4 dimensions required).

def get_batches(data):
    data = np.reshape(data, (30, 512, 512, 1))
    data = np.split(data, 30)
    return data

# %%
# Batch data
volume_batches = get_batches(train_volume)
labels_batches = get_batches(train_labels)
test_batches = get_batches(test_volume)

# %% [markdown]
# ## Data visualisation
#
# Here I have plotted an example a of picture to train on and of a picture which will serve as a label. Here you can see nicely how a electron microscopy picutre was mapped by a neuroscientist. This takes a lot of time and it would be beneficial if we were able to automate it. To watch different pictures change the values of volume_batches[i] and labels_batches[i].

# %%
plt.axis('off')
plt.imshow(volume_batches[1].reshape(512,512), cmap='Greys_r')

# %%
plt.axis('off')
plt.imshow(labels_batches[1].reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ## Model
#
# Here I've constructed the actual convolutional autoencoder. Normally an autoencoder is used for data compression or denoising. The idea is that one neural net is the encoder and learns to map feautres of the data more efficiently. Then there is a second neural net, the decoder, which learns to map this compressed representation to data of the same resolution than the input data. If you try to minimalize the difference between the input and output, the two networks will optimize and become a relativly good data compression algorithm. When doing this with images you can use CNN because they typically perform better.
#
# I have modified this architecture a bit to fit to my needs. I have used a CNN as the 'encoder' layer and let the CNN learn important features for itself during the convolutions. Then I used a deconvolutional layer as the 'decoder', but instead of minimizing the difference between the input and the output, I have set up the loss as to minimize the difference between the output and the labels.
#
# I hope that by optimizing the neural nets this way, that the convolutional layer learns to decide which are the relevant features in the electron microscopy sample, and that the deconvolutional layer learns to map from this representation of useful features to a good approximation of the labeling of the neuroscientist.

# %%
# Construct a convolutional autoencoder

# Create placeholders
inputs = tf.placeholder(dtype = tf.float32, shape=(None, 512, 512, 1), name='inputs')
targets = tf.placeholder(dtype = tf.float32, shape=(None, 512, 512, 1), name='targets')
learning_rate = 0.0001
dropout = 0.5

### Encoder
conv1 = tf.layers.conv2d(inputs, 32, 5, 1, padding='same', activation=tf.nn.relu)
maxpool1 = tf.layers.max_pooling2d(conv1, 2, 2, padding='same')
dropout1 = tf.layers.dropout(maxpool1, rate=dropout)
# Now 256x256x32
conv2 = tf.layers.conv2d(dropout1, 64, 5, 1, padding='same', activation=tf.nn.relu)
maxpool2 = tf.layers.max_pooling2d(conv2, 2, 2, padding='same')
dropout2 = tf.layers.dropout(maxpool2, rate=dropout)
# Now 128x128x64
conv3 = tf.layers.conv2d(dropout2, 128, 5, 1, padding='same', activation=tf.nn.relu)
maxpool3 = tf.layers.max_pooling2d(conv3, 2, 2, padding='same')
dropout3 = tf.layers.dropout(maxpool3, rate=dropout)
# Now 64x64x128
conv4 = tf.layers.conv2d(dropout3, 256, 5, 1, padding='same', activation=tf.nn.relu)
maxpool4 = tf.layers.max_pooling2d(conv4, 2, 2, padding='same')
dropout4 = tf.layers.dropout(maxpool4, rate=dropout)
# Now 32x32x256

conv5 = tf.layers.conv2d(dropout4, 512, 5, 1, padding='same', activation=tf.nn.relu)
encoded = tf.layers.max_pooling2d(conv5, 2, 2, padding='same')
dropout5 = tf.layers.dropout(encoded, rate=dropout)
# Now 16x16x512

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(dropout5, (32,32))
conv6 = tf.layers.conv2d(upsample1, 256, 5, 1, padding='same', activation=tf.nn.relu)
dropout6 = tf.layers.dropout(conv6, rate=dropout)
# Now 32x32x256
upsample2 = tf.image.resize_nearest_neighbor(dropout6, (64,64))
conv7 = tf.layers.conv2d(upsample2, 128, 5, 1, padding='same', activation=tf.nn.relu)
dropout7 = tf.layers.dropout(conv7, rate=dropout)
# Now 64x64x128
upsample3 = tf.image.resize_nearest_neighbor(dropout7, (128,128))
conv8 = tf.layers.conv2d(upsample3, 64, 5, 1, padding='same', activation=tf.nn.relu)
dropout8 = tf.layers.dropout(conv8, rate=dropout)
# Now 128x128x64
upsample4 = tf.image.resize_nearest_neighbor(dropout8, (256,256))
conv9 = tf.layers.conv2d(upsample4, 32, 5, 1, padding='same', activation=tf.nn.relu)
dropout9 = tf.layers.dropout(conv9, rate=dropout)
# Now 256x256x32

upsample5 = tf.image.resize_nearest_neighbor(dropout9, (512,512))
logits = tf.layers.conv2d(upsample5, 1, 5, 1, padding='same', activation=None)
dropout10 = tf.layers.dropout(logits, rate=dropout)
# Now 512x512x1
    
decoded = tf.sigmoid(dropout10, name='decoded')

# Loss and Optimizer
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits)
cost = tf.reduce_mean(loss)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training

# %%
## Function for training the Neural Network
def train_neural_network(session, optimizer, feature_batch, label_batch):
    session.run(optimizer, feed_dict = {inputs: feature_batch, targets: label_batch})

# Function for showing the stats
def print_stats(session, feature_batch, label_batch, cost):
    print("cost: ", session.run(cost, feed_dict = {inputs: feature_batch, targets: label_batch}))

# Hyperparameters
epochs = 100
batch_size = 1
          
### Train Model

# Create the session
sess = tf.Session()

# Initializing the variables
sess.run(tf.global_variables_initializer())

# Training cycle
for epoch in range(epochs):
    n_batches = len(volume_batches)
    for i in range(0, n_batches):
        train_neural_network(sess, optimizer, volume_batches[i], labels_batches[i])
        print('Epoch {:>2}, Batch {}:  '.format(epoch + 1, i), end='')
        print_stats(sess, volume_batches[i], labels_batches[i], cost)
# Out:
# Epoch  1, Batch 0:  cost:  0.624803
# Epoch  1, Batch 1:  cost:  0.556802
# Epoch  1, Batch 2:  cost:  0.706623
# Epoch  1, Batch 3:  cost:  0.573735
# Epoch  1, Batch 4:  cost:  0.589744
# Epoch  1, Batch 5:  cost:  0.613699
# Epoch  1, Batch 6:  cost:  0.605409
# Epoch  1, Batch 7:  cost:  0.612307
# Epoch  1, Batch 8:  cost:  0.606482
# Epoch  1, Batch 9:  cost:  0.560724
# Epoch  1, Batch 10:  cost:  0.562798
# Epoch  1, Batch 11:  cost:  0.55728
# Epoch  1, Batch 12:  cost:  0.603633
# Epoch  1, Batch 13:  cost:  0.527487
# Epoch  1, Batch 14:  cost:  0.494231
# Epoch  1, Batch 15:  cost:  0.513724
# Epoch  1, Batch 16:  cost:  0.517328
# Epoch  1, Batch 17:  cost:  0.539238
# Epoch  1, Batch 18:  cost:  0.507906
# Epoch  1, Batch 19:  cost:  0.540625
# Epoch  1, Batch 20:  cost:  0.539684
# Epoch  1, Batch 21:  cost:  0.51416
# Epoch  1, Batch 22:  cost:  0.510053
# Epoch  1, Batch 23:  cost:  0.502999
# Epoch  1, Batch 24:  cost:  0.484141
# Epoch  1, Batch 25:  cost:  0.50761
# Epoch  1, Batch 26:  cost:  0.513471
# Epoch  1, Batch 27:  cost:  0.522099
# Epoch  1, Batch 28:  cost:  0.510426
# Epoch  1, Batch 29:  cost:  0.457745
# Epoch  2, Batch 0:  cost:  0.539326
# Epoch  2, Batch 1:  cost:  0.54731
# Epoch  2, Batch 2:  cost:  0.564318
# Epoch  2, Batch 3:  cost:  0.562126
# Epoch  2, Batch 4:  cost:  0.581612
# Epoch  2, Batch 5:  cost:  0.588597
# Epoch  2, Batch 6:  cost:  0.560345
# Epoch  2, Batch 7:  cost:  0.560562
# Epoch  2, Batch 8:  cost:  0.551692
# Epoch  2, Batch 9:  cost:  0.543672
# Epoch  2, Batch 10:  cost:  0.554524
# Epoch  2, Batch 11:  cost:  0.544832
# Epoch  2, Batch 12:  cost:  0.569042
# Epoch  2, Batch 13:  cost:  0.521156
# Epoch  2, Batch 14:  cost:  0.485849
# Epoch  2, Batch 15:  cost:  0.508823
# Epoch  2, Batch 16:  cost:  0.504923
# Epoch  2, Batch 17:  cost:  0.532499
# Epoch  2, Batch 18:  cost:  0.495529
# Epoch  2, Batch 19:  cost:  0.530039
# Epoch  2, Batch 20:  cost:  0.538724
# Epoch  2, Batch 21:  cost:  0.51487
# Epoch  2, Batch 22:  cost:  0.515924
# Epoch  2, Batch 23:  cost:  0.503175
# Epoch  2, Batch 24:  cost:  0.480112
# Epoch  2, Batch 25:  cost:  0.51043
# Epoch  2, Batch 26:  cost:  0.511422
# Epoch  2, Batch 27:  cost:  0.518966
# Epoch  2, Batch 28:  cost:  0.50848
# Epoch  2, Batch 29:  cost:  0.462931
# Epoch  3, Batch 0:  cost:  0.529095
# Epoch  3, Batch 1:  cost:  0.538756
# Epoch  3, Batch 2:  cost:  0.563294
# Epoch  3, Batch 3:  cost:  0.559261
# Epoch  3, Batch 4:  cost:  0.575263
# Epoch  3, Batch 5:  cost:  0.580602
# Epoch  3, Batch 6:  cost:  0.554721
# Epoch  3, Batch 7:  cost:  0.557541
# Epoch  3, Batch 8:  cost:  0.552641
# Epoch  3, Batch 9:  cost:  0.531179
# Epoch  3, Batch 10:  cost:  0.549174
# Epoch  3, Batch 11:  cost:  0.545715
# Epoch  3, Batch 12:  cost:  0.567069
# Epoch  3, Batch 13:  cost:  0.515307
# Epoch  3, Batch 14:  cost:  0.483247
# Epoch  3, Batch 15:  cost:  0.504001
# Epoch  3, Batch 16:  cost:  0.499558
# Epoch  3, Batch 17:  cost:  0.529327
# Epoch  3, Batch 18:  cost:  0.490503
# Epoch  3, Batch 19:  cost:  0.524977
# Epoch  3, Batch 20:  cost:  0.533034
# Epoch  3, Batch 21:  cost:  0.512155
# Epoch  3, Batch 22:  cost:  0.517105
# Epoch  3, Batch 23:  cost:  0.504622
# Epoch  3, Batch 24:  cost:  0.476972
# Epoch  3, Batch 25:  cost:  0.50702
# Epoch  3, Batch 26:  cost:  0.512239
# Epoch  3, Batch 27:  cost:  0.520408
# Epoch  3, Batch 28:  cost:  0.508516
# Epoch  3, Batch 29:  cost:  0.462103
# Epoch  4, Batch 0:  cost:  0.525374
# Epoch  4, Batch 1:  cost:  0.535634
# Epoch  4, Batch 2:  cost:  0.559767
# Epoch  4, Batch 3:  cost:  0.557169
# Epoch  4, Batch 4:  cost:  0.573301
# Epoch  4, Batch 5:  cost:  0.57717
# Epoch  4, Batch 6:  cost:  0.551016
# Epoch  4, Batch 7:  cost:  0.553433
# Epoch  4, Batch 8:  cost:  0.548749
# Epoch  4, Batch 9:  cost:  0.526851
# Epoch  8, Batch 19:  cost:  0.471991
# Epoch  8, Batch 20:  cost:  0.489116
# Epoch  8, Batch 21:  cost:  0.474195
# Epoch  8, Batch 22:  cost:  0.469211
# Epoch  8, Batch 23:  cost:  0.458102
# Epoch  8, Batch 24:  cost:  0.444161
# Epoch  8, Batch 25:  cost:  0.461024
# Epoch  8, Batch 26:  cost:  0.471143
# Epoch  8, Batch 27:  cost:  0.483533
# Epoch  8, Batch 28:  cost:  0.468355
# Epoch  8, Batch 29:  cost:  0.420344
# Epoch  9, Batch 0:  cost:  0.490127
# Epoch  9, Batch 1:  cost:  0.506472
# Epoch  9, Batch 2:  cost:  0.516402
# Epoch  9, Batch 3:  cost:  0.525687
# Epoch  9, Batch 4:  cost:  0.543475
# Epoch  9, Batch 5:  cost:  0.542377
# Epoch  9, Batch 6:  cost:  0.514843
# Epoch  9, Batch 7:  cost:  0.519203
# Epoch  9, Batch 8:  cost:  0.500237
# Epoch  9, Batch 9:  cost:  0.48177
# Epoch  9, Batch 10:  cost:  0.501069
# Epoch  9, Batch 11:  cost:  0.500904
# Epoch  9, Batch 12:  cost:  0.508722
# Epoch  9, Batch 13:  cost:  0.471426
# Epoch  9, Batch 14:  cost:  0.431956
# Epoch  9, Batch 15:  cost:  0.454596
# Epoch  9, Batch 16:  cost:  0.448075
# Epoch  9, Batch 17:  cost:  0.475929
# Epoch  9, Batch 18:  cost:  0.434143
# Epoch  9, Batch 19:  cost:  0.45684
# Epoch  9, Batch 20:  cost:  0.485072
# Epoch  9, Batch 21:  cost:  0.452523
# Epoch  9, Batch 22:  cost:  0.455033
# Epoch  9, Batch 23:  cost:  0.446302
# Epoch  9, Batch 24:  cost:  0.427103
# Epoch  9, Batch 25:  cost:  0.451865
# Epoch  9, Batch 26:  cost:  0.4594
# Epoch  9, Batch 27:  cost:  0.468832
# Epoch  9, Batch 28:  cost:  0.455947
# Epoch  9, Batch 29:  cost:  0.409575
# Epoch 10, Batch 0:  cost:  0.481192
# Epoch 10, Batch 1:  cost:  0.499109
# Epoch 10, Batch 2:  cost:  0.506144
# Epoch 10, Batch 3:  cost:  0.517011
# Epoch 10, Batch 4:  cost:  0.532951
# Epoch 10, Batch 5:  cost:  0.532365
# Epoch 10, Batch 6:  cost:  0.504262
# Epoch 10, Batch 7:  cost:  0.509621
# Epoch 10, Batch 8:  cost:  0.488053
# Epoch 10, Batch 9:  cost:  0.472662
# Epoch 10, Batch 10:  cost:  0.487767
# Epoch 10, Batch 11:  cost:  0.498335
# Epoch 10, Batch 12:  cost:  0.498849
# Epoch 10, Batch 13:  cost:  0.461892
# Epoch 10, Batch 14:  cost:  0.418148
# Epoch 10, Batch 15:  cost:  0.44216
# Epoch 10, Batch 16:  cost:  0.43471
# Epoch 10, Batch 17:  cost:  0.460485
# Epoch 10, Batch 18:  cost:  0.4188
# Epoch 10, Batch 19:  cost:  0.439608
# Epoch 10, Batch 20:  cost:  0.466644
# Epoch 10, Batch 21:  cost:  0.437324
# Epoch 10, Batch 22:  cost:  0.448383
# Epoch 10, Batch 23:  cost:  0.44358
# Epoch 17, Batch 8:  cost:  0.420247
# Epoch 17, Batch 9:  cost:  0.416601
# Epoch 17, Batch 10:  cost:  0.415503
# Epoch 17, Batch 11:  cost:  0.407415
# Epoch 17, Batch 12:  cost:  0.405501
# Epoch 17, Batch 13:  cost:  0.382814
# Epoch 17, Batch 14:  cost:  0.354659
# Epoch 17, Batch 15:  cost:  0.354145
# Epoch 17, Batch 16:  cost:  0.347046
# Epoch 17, Batch 17:  cost:  0.357556
# Epoch 17, Batch 18:  cost:  0.33995
# Epoch 17, Batch 19:  cost:  0.35765
# Epoch 17, Batch 20:  cost:  0.381884
# Epoch 17, Batch 21:  cost:  0.350141
# Epoch 17, Batch 22:  cost:  0.351809
# Epoch 17, Batch 23:  cost:  0.363648
# Epoch 17, Batch 24:  cost:  0.351305
# Epoch 17, Batch 25:  cost:  0.369595
# Epoch 17, Batch 26:  cost:  0.378314
# Epoch 17, Batch 27:  cost:  0.382515
# Epoch 17, Batch 28:  cost:  0.380667
# Epoch 17, Batch 29:  cost:  0.355384
# Epoch 18, Batch 0:  cost:  0.429735
# Epoch 18, Batch 1:  cost:  0.432314
# Epoch 18, Batch 2:  cost:  0.431733
# Epoch 18, Batch 3:  cost:  0.441876
# Epoch 18, Batch 4:  cost:  0.460542
# Epoch 18, Batch 5:  cost:  0.458028
# Epoch 18, Batch 6:  cost:  0.442591
# Epoch 18, Batch 7:  cost:  0.429899
# Epoch 18, Batch 8:  cost:  0.411351
# Epoch 18, Batch 9:  cost:  0.408619
# Epoch 18, Batch 10:  cost:  0.405866
# Epoch 18, Batch 11:  cost:  0.39537
# Epoch 18, Batch 12:  cost:  0.39161
# Epoch 18, Batch 13:  cost:  0.375416
# Epoch 18, Batch 14:  cost:  0.349855
# Epoch 18, Batch 15:  cost:  0.34402
# Epoch 18, Batch 16:  cost:  0.33624
# Epoch 18, Batch 17:  cost:  0.345871
# Epoch 18, Batch 18:  cost:  0.328646
# Epoch 18, Batch 19:  cost:  0.34512
# Epoch 18, Batch 20:  cost:  0.364452
# Epoch 18, Batch 21:  cost:  0.33473
# Epoch 18, Batch 22:  cost:  0.332194
# Epoch 18, Batch 23:  cost:  0.351589
# Epoch 18, Batch 24:  cost:  0.345041
# Epoch 18, Batch 25:  cost:  0.356553
# Epoch 18, Batch 26:  cost:  0.362263
# Epoch 18, Batch 27:  cost:  0.365937
# Epoch 18, Batch 28:  cost:  0.373573
# Epoch 18, Batch 29:  cost:  0.351565
# Epoch 19, Batch 0:  cost:  0.419974
# Epoch 19, Batch 1:  cost:  0.416625
# Epoch 19, Batch 2:  cost:  0.423222
# Epoch 19, Batch 3:  cost:  0.431863
# Epoch 19, Batch 4:  cost:  0.451545
# Epoch 19, Batch 5:  cost:  0.45377
# Epoch 19, Batch 6:  cost:  0.439707
# Epoch 19, Batch 7:  cost:  0.419444
# Epoch 19, Batch 8:  cost:  0.401888
# Epoch 19, Batch 9:  cost:  0.400554
# Epoch 19, Batch 10:  cost:  0.38961
# Epoch 19, Batch 11:  cost:  0.385532
# Epoch 19, Batch 12:  cost:  0.381376
# Epoch 19, Batch 13:  cost:  0.359448
# Epoch 19, Batch 14:  cost:  0.329703
# Epoch 19, Batch 15:  cost:  0.328119
# Epoch 19, Batch 16:  cost:  0.325369
# Epoch 19, Batch 17:  cost:  0.338004
# Epoch 19, Batch 18:  cost:  0.318509
# Epoch 19, Batch 19:  cost:  0.332459
# Epoch 19, Batch 20:  cost:  0.348407
# Epoch 19, Batch 21:  cost:  0.328079
# Epoch 19, Batch 22:  cost:  0.32824
# Epoch 19, Batch 23:  cost:  0.339862
# Epoch 19, Batch 24:  cost:  0.328957
# Epoch 19, Batch 25:  cost:  0.340943
# Epoch 19, Batch 26:  cost:  0.347738
# Epoch 19, Batch 27:  cost:  0.35182
# Epoch 19, Batch 28:  cost:  0.358447
# Epoch 19, Batch 29:  cost:  0.343888
# Epoch 20, Batch 0:  cost:  0.408612
# Epoch 20, Batch 1:  cost:  0.40517
# Epoch 20, Batch 2:  cost:  0.405942
# Epoch 20, Batch 3:  cost:  0.419033
# Epoch 20, Batch 4:  cost:  0.437165
# Epoch 20, Batch 5:  cost:  0.44021
# Epoch 20, Batch 6:  cost:  0.424446
# Epoch 20, Batch 7:  cost:  0.404382
# Epoch 20, Batch 8:  cost:  0.395007
# Epoch 20, Batch 9:  cost:  0.389075
# Epoch 20, Batch 10:  cost:  0.383185
# Epoch 20, Batch 11:  cost:  0.375435
# Epoch 20, Batch 12:  cost:  0.370667
# Epoch 20, Batch 13:  cost:  0.351344
# Epoch 20, Batch 14:  cost:  0.323771
# Epoch 20, Batch 15:  cost:  0.318124
# Epoch 20, Batch 16:  cost:  0.318813
# Epoch 20, Batch 17:  cost:  0.322309
# Epoch 20, Batch 18:  cost:  0.308945
# Epoch 20, Batch 19:  cost:  0.322836
# Epoch 20, Batch 20:  cost:  0.336081
# Epoch 20, Batch 21:  cost:  0.314147
# Epoch 20, Batch 22:  cost:  0.311642
# Epoch 20, Batch 23:  cost:  0.325094
# Epoch 20, Batch 24:  cost:  0.318716
# Epoch 20, Batch 25:  cost:  0.327621
# Epoch 20, Batch 26:  cost:  0.337054
# Epoch 20, Batch 27:  cost:  0.341169
# Epoch 20, Batch 28:  cost:  0.345123
# Epoch 20, Batch 29:  cost:  0.332838
# Epoch 21, Batch 0:  cost:  0.389846
# Epoch 21, Batch 1:  cost:  0.388954
# Epoch 21, Batch 2:  cost:  0.39223
# Epoch 21, Batch 3:  cost:  0.404709
# Epoch 21, Batch 4:  cost:  0.422272
# Epoch 21, Batch 5:  cost:  0.425205
# Epoch 21, Batch 6:  cost:  0.409416
# Epoch 21, Batch 7:  cost:  0.389181
# Epoch 21, Batch 8:  cost:  0.38267
# Epoch 21, Batch 9:  cost:  0.3758
# Epoch 21, Batch 10:  cost:  0.363803
# Epoch 21, Batch 11:  cost:  0.359424
# Epoch 21, Batch 12:  cost:  0.356155
# Epoch 21, Batch 13:  cost:  0.342055
# Epoch 21, Batch 14:  cost:  0.316116
# Epoch 21, Batch 15:  cost:  0.311513
# Epoch 21, Batch 16:  cost:  0.312606
# Epoch 21, Batch 17:  cost:  0.314136
# Epoch 21, Batch 18:  cost:  0.302808
# Epoch 21, Batch 19:  cost:  0.311876
# Epoch 21, Batch 20:  cost:  0.326376
# Epoch 21, Batch 21:  cost:  0.307984
# Epoch 21, Batch 22:  cost:  0.306479
# Epoch 21, Batch 23:  cost:  0.317854
# Epoch 21, Batch 24:  cost:  0.30609
# Epoch 21, Batch 25:  cost:  0.315253
# Epoch 21, Batch 26:  cost:  0.324899
# Epoch 21, Batch 27:  cost:  0.329876
# Epoch 21, Batch 28:  cost:  0.332115
# Epoch 21, Batch 29:  cost:  0.319367
# Epoch 22, Batch 0:  cost:  0.372975
# Epoch 22, Batch 1:  cost:  0.373951
# Epoch 22, Batch 2:  cost:  0.382217
# Epoch 22, Batch 3:  cost:  0.394796
# Epoch 22, Batch 4:  cost:  0.409529
# Epoch 22, Batch 5:  cost:  0.413619
# Epoch 22, Batch 6:  cost:  0.40168
# Epoch 22, Batch 7:  cost:  0.379356
# Epoch 22, Batch 8:  cost:  0.374292
# Epoch 22, Batch 9:  cost:  0.368235
# Epoch 22, Batch 10:  cost:  0.357277
# Epoch 22, Batch 11:  cost:  0.353627
# Epoch 22, Batch 12:  cost:  0.341175
# Epoch 22, Batch 13:  cost:  0.331859
# Epoch 22, Batch 14:  cost:  0.306008
# Epoch 22, Batch 15:  cost:  0.302705
# Epoch 22, Batch 16:  cost:  0.307691
# Epoch 22, Batch 17:  cost:  0.312356
# Epoch 22, Batch 18:  cost:  0.297247
# Epoch 22, Batch 19:  cost:  0.307789
# Epoch 22, Batch 20:  cost:  0.320554
# Epoch 22, Batch 21:  cost:  0.300629
# Epoch 22, Batch 22:  cost:  0.311895
# Epoch 22, Batch 23:  cost:  0.322677
# Epoch 22, Batch 24:  cost:  0.30709
# Epoch 22, Batch 25:  cost:  0.314305
# Epoch 22, Batch 26:  cost:  0.323433
# Epoch 22, Batch 27:  cost:  0.332009
# Epoch 22, Batch 28:  cost:  0.336929
# Epoch 22, Batch 29:  cost:  0.314165
# Epoch 23, Batch 0:  cost:  0.368256
# Epoch 23, Batch 1:  cost:  0.365426
# Epoch 23, Batch 2:  cost:  0.368865
# Epoch 23, Batch 3:  cost:  0.38406
# Epoch 23, Batch 4:  cost:  0.406386
# Epoch 23, Batch 5:  cost:  0.412857
# Epoch 23, Batch 6:  cost:  0.400211
# Epoch 23, Batch 7:  cost:  0.376337
# Epoch 23, Batch 8:  cost:  0.371797
# Epoch 23, Batch 9:  cost:  0.374804
# Epoch 23, Batch 10:  cost:  0.351576
# Epoch 23, Batch 11:  cost:  0.346627
# Epoch 23, Batch 12:  cost:  0.337913
# Epoch 23, Batch 13:  cost:  0.337707
# Epoch 23, Batch 14:  cost:  0.30388
# Epoch 23, Batch 15:  cost:  0.296688
# Epoch 23, Batch 16:  cost:  0.301014
# Epoch 23, Batch 17:  cost:  0.305855
# Epoch 23, Batch 18:  cost:  0.295006
# Epoch 23, Batch 19:  cost:  0.304302
# Epoch 23, Batch 20:  cost:  0.317278
# Epoch 25, Batch 26:  cost:  0.288191
# Epoch 25, Batch 27:  cost:  0.305887
# Epoch 25, Batch 28:  cost:  0.308072
# Epoch 25, Batch 29:  cost:  0.291249
# Epoch 26, Batch 0:  cost:  0.338389
# Epoch 26, Batch 1:  cost:  0.337749
# Epoch 26, Batch 2:  cost:  0.345409
# Epoch 26, Batch 3:  cost:  0.361721
# Epoch 26, Batch 4:  cost:  0.368072
# Epoch 26, Batch 5:  cost:  0.368031
# Epoch 26, Batch 6:  cost:  0.364692
# Epoch 26, Batch 7:  cost:  0.342235
# Epoch 26, Batch 8:  cost:  0.335759
# Epoch 26, Batch 9:  cost:  0.332915
# Epoch 26, Batch 10:  cost:  0.320693
# Epoch 26, Batch 11:  cost:  0.311296
# Epoch 26, Batch 12:  cost:  0.301474
# Epoch 26, Batch 13:  cost:  0.298884
# Epoch 26, Batch 14:  cost:  0.280205
# Epoch 26, Batch 15:  cost:  0.272005
# Epoch 26, Batch 16:  cost:  0.271968
# Epoch 26, Batch 17:  cost:  0.273333
# Epoch 26, Batch 18:  cost:  0.264973
# Epoch 26, Batch 19:  cost:  0.284679
# Epoch 26, Batch 20:  cost:  0.285697
# Epoch 26, Batch 21:  cost:  0.253993
# Epoch 26, Batch 22:  cost:  0.262293
# Epoch 26, Batch 23:  cost:  0.282791
# Epoch 26, Batch 24:  cost:  0.284646
# Epoch 26, Batch 25:  cost:  0.290625
# Epoch 26, Batch 26:  cost:  0.297174
# Epoch 26, Batch 27:  cost:  0.303437
# Epoch 26, Batch 28:  cost:  0.302472
# Epoch 26, Batch 29:  cost:  0.291615
# Epoch 27, Batch 0:  cost:  0.335052
# Epoch 27, Batch 1:  cost:  0.32901
# Epoch 27, Batch 2:  cost:  0.336589
# Epoch 27, Batch 3:  cost:  0.354718
# Epoch 27, Batch 4:  cost:  0.365712
# Epoch 27, Batch 5:  cost:  0.369828
# Epoch 27, Batch 6:  cost:  0.360489
# Epoch 27, Batch 7:  cost:  0.333679
# Epoch 27, Batch 8:  cost:  0.330057
# Epoch 27, Batch 9:  cost:  0.332659
# Epoch 27, Batch 10:  cost:  0.327426
# Epoch 27, Batch 11:  cost:  0.312267
# Epoch 27, Batch 12:  cost:  0.300617
# Epoch 27, Batch 13:  cost:  0.290645
# Epoch 27, Batch 14:  cost:  0.274318
# Epoch 27, Batch 15:  cost:  0.271241
# Epoch 27, Batch 16:  cost:  0.274019
# Epoch 27, Batch 17:  cost:  0.27133
# Epoch 27, Batch 18:  cost:  0.258083
# Epoch 27, Batch 19:  cost:  0.27285
# Epoch 27, Batch 20:  cost:  0.280772
# Epoch 27, Batch 21:  cost:  0.262994
# Epoch 27, Batch 22:  cost:  0.269016
# Epoch 27, Batch 23:  cost:  0.282011
# Epoch 27, Batch 24:  cost:  0.272395
# Epoch 27, Batch 25:  cost:  0.276892
# Epoch 27, Batch 26:  cost:  0.292014
# Epoch 27, Batch 27:  cost:  0.305916
# Epoch 27, Batch 28:  cost:  0.307261
# Epoch 27, Batch 29:  cost:  0.295161
# Epoch 28, Batch 0:  cost:  0.337507
# Epoch 28, Batch 1:  cost:  0.329765
# Epoch 28, Batch 2:  cost:  0.335809
# Epoch 28, Batch 3:  cost:  0.340583
# Epoch 28, Batch 4:  cost:  0.354231
# Epoch 28, Batch 5:  cost:  0.361278
# Epoch 28, Batch 6:  cost:  0.354918
# Epoch 28, Batch 7:  cost:  0.330068
# Epoch 28, Batch 8:  cost:  0.328977
# Epoch 28, Batch 9:  cost:  0.333971
# Epoch 28, Batch 10:  cost:  0.322183
# Epoch 28, Batch 11:  cost:  0.305862
# Epoch 28, Batch 12:  cost:  0.287728
# Epoch 28, Batch 13:  cost:  0.286609
# Epoch 28, Batch 14:  cost:  0.266655
# Epoch 28, Batch 15:  cost:  0.261412
# Epoch 28, Batch 16:  cost:  0.26677
# Epoch 28, Batch 17:  cost:  0.269743
# Epoch 28, Batch 18:  cost:  0.256111
# Epoch 28, Batch 19:  cost:  0.270302
# Epoch 28, Batch 20:  cost:  0.276903
# Epoch 28, Batch 21:  cost:  0.248349
# Epoch 28, Batch 22:  cost:  0.248425
# Epoch 28, Batch 23:  cost:  0.266896
# Epoch 28, Batch 24:  cost:  0.268552
# Epoch 28, Batch 25:  cost:  0.266375
# Epoch 28, Batch 26:  cost:  0.280242
# Epoch 28, Batch 27:  cost:  0.295503
# Epoch 28, Batch 28:  cost:  0.301898
# Epoch 28, Batch 29:  cost:  0.293971
# Epoch 29, Batch 0:  cost:  0.338836
# Epoch 29, Batch 1:  cost:  0.325223
# Epoch 29, Batch 2:  cost:  0.324797
# Epoch 29, Batch 3:  cost:  0.333996
# Epoch 29, Batch 4:  cost:  0.345485
# Epoch 29, Batch 5:  cost:  0.346331
# Epoch 29, Batch 6:  cost:  0.350471
# Epoch 29, Batch 7:  cost:  0.318668
# Epoch 29, Batch 8:  cost:  0.319043
# Epoch 29, Batch 9:  cost:  0.322139
# Epoch 29, Batch 10:  cost:  0.313085
# Epoch 29, Batch 11:  cost:  0.30163
# Epoch 29, Batch 12:  cost:  0.281471
# Epoch 29, Batch 13:  cost:  0.277844
# Epoch 29, Batch 14:  cost:  0.268846
# Epoch 29, Batch 15:  cost:  0.260813
# Epoch 29, Batch 16:  cost:  0.26357
# Epoch 29, Batch 17:  cost:  0.260617
# Epoch 29, Batch 18:  cost:  0.249448
# Epoch 29, Batch 19:  cost:  0.263353
# Epoch 29, Batch 20:  cost:  0.270941
# Epoch 29, Batch 21:  cost:  0.24408
# Epoch 29, Batch 22:  cost:  0.249173
# Epoch 29, Batch 23:  cost:  0.259726
# Epoch 29, Batch 24:  cost:  0.259172
# Epoch 29, Batch 25:  cost:  0.257306
# Epoch 29, Batch 26:  cost:  0.276161
# Epoch 29, Batch 27:  cost:  0.286887
# Epoch 29, Batch 28:  cost:  0.289893
# Epoch 29, Batch 29:  cost:  0.285607
# Epoch 30, Batch 0:  cost:  0.32865
# Epoch 30, Batch 1:  cost:  0.318018
# Epoch 30, Batch 2:  cost:  0.322061
# Epoch 30, Batch 3:  cost:  0.328434
# Epoch 30, Batch 4:  cost:  0.337988
# Epoch 30, Batch 5:  cost:  0.338321
# Epoch 30, Batch 6:  cost:  0.332479
# Epoch 30, Batch 7:  cost:  0.307603
# Epoch 30, Batch 8:  cost:  0.30835
# Epoch 30, Batch 9:  cost:  0.311247
# Epoch 30, Batch 10:  cost:  0.30109
# Epoch 30, Batch 11:  cost:  0.301077
# Epoch 30, Batch 12:  cost:  0.280983
# Epoch 30, Batch 13:  cost:  0.265328
# Epoch 30, Batch 14:  cost:  0.245872
# Epoch 30, Batch 15:  cost:  0.241844
# Epoch 30, Batch 16:  cost:  0.249637
# Epoch 30, Batch 17:  cost:  0.256381
# Epoch 30, Batch 18:  cost:  0.253199
# Epoch 30, Batch 19:  cost:  0.263071
# Epoch 30, Batch 20:  cost:  0.266833
# Epoch 30, Batch 21:  cost:  0.23855
# Epoch 30, Batch 22:  cost:  0.23913
# Epoch 30, Batch 23:  cost:  0.255806
# Epoch 30, Batch 24:  cost:  0.252352
# Epoch 30, Batch 25:  cost:  0.258783
# Epoch 30, Batch 26:  cost:  0.269966
# Epoch 30, Batch 27:  cost:  0.286926
# Epoch 30, Batch 28:  cost:  0.289137
# Epoch 30, Batch 29:  cost:  0.273638
# Epoch 31, Batch 0:  cost:  0.313269
# Epoch 31, Batch 1:  cost:  0.307003
# Epoch 31, Batch 2:  cost:  0.314511
# Epoch 31, Batch 3:  cost:  0.317935
# Epoch 31, Batch 4:  cost:  0.331741
# Epoch 31, Batch 5:  cost:  0.333821
# Epoch 31, Batch 6:  cost:  0.329193
# Epoch 31, Batch 7:  cost:  0.310024
# Epoch 31, Batch 8:  cost:  0.305786
# Epoch 31, Batch 9:  cost:  0.302526
# Epoch 31, Batch 10:  cost:  0.295809
# Epoch 31, Batch 11:  cost:  0.285165
# Epoch 31, Batch 12:  cost:  0.26034
# Epoch 31, Batch 13:  cost:  0.259528
# Epoch 31, Batch 14:  cost:  0.248333
# Epoch 31, Batch 15:  cost:  0.252619
# Epoch 31, Batch 16:  cost:  0.248042
# Epoch 31, Batch 17:  cost:  0.244199
# Epoch 31, Batch 18:  cost:  0.235824
# Epoch 31, Batch 19:  cost:  0.249144
# Epoch 31, Batch 20:  cost:  0.258145
# Epoch 31, Batch 21:  cost:  0.235222
# Epoch 31, Batch 22:  cost:  0.236739
# Epoch 31, Batch 23:  cost:  0.254228
# Epoch 31, Batch 24:  cost:  0.249504
# Epoch 31, Batch 25:  cost:  0.25233
# Epoch 31, Batch 26:  cost:  0.258806
# Epoch 31, Batch 27:  cost:  0.273063
# Epoch 31, Batch 28:  cost:  0.277108
# Epoch 31, Batch 29:  cost:  0.264691
# Epoch 32, Batch 0:  cost:  0.313347
# Epoch 32, Batch 1:  cost:  0.304923
# Epoch 32, Batch 2:  cost:  0.307575
# Epoch 32, Batch 3:  cost:  0.306585
# Epoch 32, Batch 4:  cost:  0.312114
# Epoch 32, Batch 5:  cost:  0.311268
# Epoch 32, Batch 6:  cost:  0.314978
# Epoch 32, Batch 7:  cost:  0.292862
# Epoch 32, Batch 8:  cost:  0.293072
# Epoch 32, Batch 9:  cost:  0.294291
# Epoch 36, Batch 19:  cost:  0.228717
# Epoch 36, Batch 20:  cost:  0.231127
# Epoch 36, Batch 21:  cost:  0.217055
# Epoch 36, Batch 22:  cost:  0.217299
# Epoch 36, Batch 23:  cost:  0.237868
# Epoch 36, Batch 24:  cost:  0.241146
# Epoch 36, Batch 25:  cost:  0.249384
# Epoch 36, Batch 26:  cost:  0.257108
# Epoch 36, Batch 27:  cost:  0.263264
# Epoch 36, Batch 28:  cost:  0.252814
# Epoch 36, Batch 29:  cost:  0.242607
# Epoch 37, Batch 0:  cost:  0.288383
# Epoch 37, Batch 1:  cost:  0.280316
# Epoch 37, Batch 2:  cost:  0.288323
# Epoch 37, Batch 3:  cost:  0.281174
# Epoch 37, Batch 4:  cost:  0.28737
# Epoch 37, Batch 5:  cost:  0.283932
# Epoch 37, Batch 6:  cost:  0.293307
# Epoch 37, Batch 7:  cost:  0.269773
# Epoch 37, Batch 8:  cost:  0.266878
# Epoch 37, Batch 9:  cost:  0.274291
# Epoch 37, Batch 10:  cost:  0.25345
# Epoch 37, Batch 11:  cost:  0.24702
# Epoch 37, Batch 12:  cost:  0.222572
# Epoch 37, Batch 13:  cost:  0.21973
# Epoch 37, Batch 14:  cost:  0.216954
# Epoch 37, Batch 15:  cost:  0.210052
# Epoch 37, Batch 16:  cost:  0.207655
# Epoch 37, Batch 17:  cost:  0.203573
# Epoch 37, Batch 18:  cost:  0.202927
# Epoch 37, Batch 19:  cost:  0.215274
# Epoch 37, Batch 20:  cost:  0.227389
# Epoch 37, Batch 21:  cost:  0.205398
# Epoch 37, Batch 22:  cost:  0.213879
# Epoch 37, Batch 23:  cost:  0.230007
# Epoch 37, Batch 24:  cost:  0.225238
# Epoch 37, Batch 25:  cost:  0.223547
# Epoch 37, Batch 26:  cost:  0.229385
# Epoch 37, Batch 27:  cost:  0.243653
# Epoch 37, Batch 28:  cost:  0.239987
# Epoch 37, Batch 29:  cost:  0.235048
# Epoch 38, Batch 0:  cost:  0.2817
# Epoch 38, Batch 1:  cost:  0.26856
# Epoch 38, Batch 2:  cost:  0.269315
# Epoch 38, Batch 3:  cost:  0.264472
# Epoch 38, Batch 4:  cost:  0.270458
# Epoch 38, Batch 5:  cost:  0.263553
# Epoch 38, Batch 6:  cost:  0.268243
# Epoch 38, Batch 7:  cost:  0.244662
# Epoch 38, Batch 8:  cost:  0.247917
# Epoch 38, Batch 9:  cost:  0.258475
# Epoch 38, Batch 10:  cost:  0.244021
# Epoch 38, Batch 11:  cost:  0.237135
# Epoch 38, Batch 12:  cost:  0.209774
# Epoch 38, Batch 13:  cost:  0.204956
# Epoch 38, Batch 14:  cost:  0.198932
# Epoch 38, Batch 15:  cost:  0.195155
# Epoch 38, Batch 16:  cost:  0.194642
# Epoch 38, Batch 17:  cost:  0.195339
# Epoch 38, Batch 18:  cost:  0.192735
# Epoch 38, Batch 19:  cost:  0.203312
# Epoch 38, Batch 20:  cost:  0.207216
# Epoch 38, Batch 21:  cost:  0.183878
# Epoch 38, Batch 22:  cost:  0.191668
# Epoch 40, Batch 28:  cost:  0.231968
# Epoch 40, Batch 29:  cost:  0.226984
# Epoch 41, Batch 0:  cost:  0.263248
# Epoch 41, Batch 1:  cost:  0.253845
# Epoch 41, Batch 2:  cost:  0.253857
# Epoch 41, Batch 3:  cost:  0.255292
# Epoch 41, Batch 4:  cost:  0.26949
# Epoch 41, Batch 5:  cost:  0.266905
# Epoch 41, Batch 6:  cost:  0.266307
# Epoch 41, Batch 7:  cost:  0.240698
# Epoch 41, Batch 8:  cost:  0.237853
# Epoch 41, Batch 9:  cost:  0.242291
# Epoch 41, Batch 10:  cost:  0.229529
# Epoch 41, Batch 11:  cost:  0.225019
# Epoch 41, Batch 12:  cost:  0.198906
# Epoch 41, Batch 13:  cost:  0.207624
# Epoch 41, Batch 14:  cost:  0.199567
# Epoch 41, Batch 15:  cost:  0.194128
# Epoch 41, Batch 16:  cost:  0.191869
# Epoch 41, Batch 17:  cost:  0.194769
# Epoch 41, Batch 18:  cost:  0.188705
# Epoch 41, Batch 19:  cost:  0.198382
# Epoch 41, Batch 20:  cost:  0.210013
# Epoch 41, Batch 21:  cost:  0.185577
# Epoch 41, Batch 22:  cost:  0.184473
# Epoch 41, Batch 23:  cost:  0.204955
# Epoch 41, Batch 24:  cost:  0.205893
# Epoch 41, Batch 25:  cost:  0.204629
# Epoch 41, Batch 26:  cost:  0.212642
# Epoch 41, Batch 27:  cost:  0.2256
# Epoch 41, Batch 28:  cost:  0.228924
# Epoch 41, Batch 29:  cost:  0.23892
# Epoch 42, Batch 0:  cost:  0.269838
# Epoch 42, Batch 1:  cost:  0.251478
# Epoch 42, Batch 2:  cost:  0.245773
# Epoch 42, Batch 3:  cost:  0.242897
# Epoch 42, Batch 4:  cost:  0.253025
# Epoch 42, Batch 5:  cost:  0.245097
# Epoch 42, Batch 6:  cost:  0.248926
# Epoch 42, Batch 7:  cost:  0.229922
# Epoch 42, Batch 8:  cost:  0.23356
# Epoch 42, Batch 9:  cost:  0.242013
# Epoch 42, Batch 10:  cost:  0.233153
# Epoch 42, Batch 11:  cost:  0.220307
# Epoch 42, Batch 12:  cost:  0.194298
# Epoch 42, Batch 13:  cost:  0.193865
# Epoch 42, Batch 14:  cost:  0.193946
# Epoch 42, Batch 15:  cost:  0.184789
# Epoch 42, Batch 16:  cost:  0.182132
# Epoch 42, Batch 17:  cost:  0.182481
# Epoch 42, Batch 18:  cost:  0.182523
# Epoch 42, Batch 19:  cost:  0.197351
# Epoch 42, Batch 20:  cost:  0.200764
# Epoch 42, Batch 21:  cost:  0.171539
# Epoch 42, Batch 22:  cost:  0.172693
# Epoch 42, Batch 23:  cost:  0.190516
# Epoch 42, Batch 24:  cost:  0.192526
# Epoch 42, Batch 25:  cost:  0.203521
# Epoch 42, Batch 26:  cost:  0.214695
# Epoch 42, Batch 27:  cost:  0.228035
# Epoch 42, Batch 28:  cost:  0.223417
# Epoch 42, Batch 29:  cost:  0.218313
# Epoch 43, Batch 0:  cost:  0.254994
# Epoch 43, Batch 1:  cost:  0.236249
# Epoch 43, Batch 2:  cost:  0.236116
# Epoch 43, Batch 3:  cost:  0.237586
# Epoch 43, Batch 4:  cost:  0.248791
# Epoch 43, Batch 5:  cost:  0.23646
# Epoch 43, Batch 6:  cost:  0.240999
# Epoch 43, Batch 7:  cost:  0.219602
# Epoch 43, Batch 8:  cost:  0.218465
# Epoch 43, Batch 9:  cost:  0.225165
# Epoch 43, Batch 10:  cost:  0.209196
# Epoch 43, Batch 11:  cost:  0.204345
# Epoch 43, Batch 12:  cost:  0.181205
# Epoch 43, Batch 13:  cost:  0.181341
# Epoch 43, Batch 14:  cost:  0.183855
# Epoch 43, Batch 15:  cost:  0.178427
# Epoch 43, Batch 16:  cost:  0.173951
# Epoch 43, Batch 17:  cost:  0.166757
# Epoch 43, Batch 18:  cost:  0.164189
# Epoch 43, Batch 19:  cost:  0.17352
# Epoch 43, Batch 20:  cost:  0.183071
# Epoch 43, Batch 21:  cost:  0.166808
# Epoch 43, Batch 22:  cost:  0.171679
# Epoch 43, Batch 23:  cost:  0.187606
# Epoch 43, Batch 24:  cost:  0.186913
# Epoch 43, Batch 25:  cost:  0.196786
# Epoch 43, Batch 26:  cost:  0.206168
# Epoch 43, Batch 27:  cost:  0.219028
# Epoch 43, Batch 28:  cost:  0.222204
# Epoch 43, Batch 29:  cost:  0.227892
# Epoch 44, Batch 0:  cost:  0.25836
# Epoch 44, Batch 1:  cost:  0.24424
# Epoch 44, Batch 2:  cost:  0.242644
# Epoch 44, Batch 3:  cost:  0.242463
# Epoch 44, Batch 4:  cost:  0.251891
# Epoch 44, Batch 5:  cost:  0.238298
# Epoch 44, Batch 6:  cost:  0.239658
# Epoch 44, Batch 7:  cost:  0.219149
# Epoch 44, Batch 8:  cost:  0.22341
# Epoch 44, Batch 9:  cost:  0.230864
# Epoch 44, Batch 10:  cost:  0.218243
# Epoch 44, Batch 11:  cost:  0.218972
# Epoch 44, Batch 12:  cost:  0.188967
# Epoch 44, Batch 13:  cost:  0.186225
# Epoch 44, Batch 14:  cost:  0.182178
# Epoch 44, Batch 15:  cost:  0.178878
# Epoch 44, Batch 16:  cost:  0.184405
# Epoch 44, Batch 17:  cost:  0.187984
# Epoch 44, Batch 18:  cost:  0.181398
# Epoch 44, Batch 19:  cost:  0.188498
# Epoch 44, Batch 20:  cost:  0.189556
# Epoch 44, Batch 21:  cost:  0.164004
# Epoch 44, Batch 22:  cost:  0.165423
# ...
# Epoch 86, Batch 16:  cost:  0.111275
# Epoch 86, Batch 17:  cost:  0.111865
# Epoch 86, Batch 18:  cost:  0.107623
# Epoch 86, Batch 19:  cost:  0.10624
# Epoch 86, Batch 20:  cost:  0.106015
# Epoch 86, Batch 21:  cost:  0.0989768
# Epoch 86, Batch 22:  cost:  0.0981046
# Epoch 86, Batch 23:  cost:  0.10821
# Epoch 86, Batch 24:  cost:  0.113733
# Epoch 86, Batch 25:  cost:  0.118517
# Epoch 86, Batch 26:  cost:  0.120117
# Epoch 86, Batch 27:  cost:  0.132152
# Epoch 86, Batch 28:  cost:  0.13234
# Epoch 86, Batch 29:  cost:  0.13077
# Epoch 89, Batch 4:  cost:  0.126591
# Epoch 89, Batch 5:  cost:  0.133113
# Epoch 89, Batch 6:  cost:  0.14549
# Epoch 89, Batch 7:  cost:  0.132577
# Epoch 89, Batch 8:  cost:  0.132643
# Epoch 89, Batch 9:  cost:  0.143527
# Epoch 89, Batch 10:  cost:  0.136699
# Epoch 89, Batch 11:  cost:  0.130415
# Epoch 89, Batch 12:  cost:  0.115908
# Epoch 89, Batch 13:  cost:  0.118924
# Epoch 89, Batch 14:  cost:  0.12286
# Epoch 89, Batch 15:  cost:  0.120849
# Epoch 89, Batch 16:  cost:  0.11334
# Epoch 89, Batch 17:  cost:  0.111572
# Epoch 89, Batch 18:  cost:  0.107255
# Epoch 89, Batch 19:  cost:  0.107979
# Epoch 89, Batch 20:  cost:  0.107871
# Epoch 89, Batch 21:  cost:  0.0955137
# Epoch 89, Batch 22:  cost:  0.094706
# Epoch 89, Batch 23:  cost:  0.105008
# Epoch 89, Batch 24:  cost:  0.11304
# Epoch 89, Batch 25:  cost:  0.111438
# Epoch 89, Batch 26:  cost:  0.112055
# Epoch 89, Batch 27:  cost:  0.123598
# Epoch 89, Batch 28:  cost:  0.122938
# Epoch 89, Batch 29:  cost:  0.122462
# Epoch 90, Batch 0:  cost:  0.144247
# Epoch 90, Batch 1:  cost:  0.130089
# Epoch 90, Batch 2:  cost:  0.129233
# Epoch 90, Batch 3:  cost:  0.121079
# Epoch 90, Batch 4:  cost:  0.128496
# Epoch 90, Batch 5:  cost:  0.13098
# Epoch 90, Batch 6:  cost:  0.135774
# Epoch 90, Batch 7:  cost:  0.120933
# Epoch 90, Batch 8:  cost:  0.122171
# Epoch 90, Batch 9:  cost:  0.131192
# Epoch 90, Batch 10:  cost:  0.123526
# Epoch 90, Batch 11:  cost:  0.11869
# Epoch 90, Batch 12:  cost:  0.109952
# Epoch 90, Batch 13:  cost:  0.115194
# Epoch 90, Batch 14:  cost:  0.120964
# Epoch 90, Batch 15:  cost:  0.120701
# Epoch 90, Batch 16:  cost:  0.10985
# Epoch 90, Batch 17:  cost:  0.112069
# Epoch 90, Batch 18:  cost:  0.102072
# Epoch 90, Batch 19:  cost:  0.0993385
# Epoch 90, Batch 20:  cost:  0.101059
# Epoch 90, Batch 21:  cost:  0.0914096
# Epoch 90, Batch 22:  cost:  0.0933829
# Epoch 90, Batch 23:  cost:  0.107261
# Epoch 90, Batch 24:  cost:  0.108797
# Epoch 90, Batch 25:  cost:  0.111786
# Epoch 90, Batch 26:  cost:  0.113431
# Epoch 90, Batch 27:  cost:  0.125488
# Epoch 90, Batch 28:  cost:  0.12784
# Epoch 90, Batch 29:  cost:  0.125527
# Epoch 91, Batch 0:  cost:  0.144183
# Epoch 91, Batch 1:  cost:  0.131785
# Epoch 91, Batch 2:  cost:  0.127026
# Epoch 91, Batch 3:  cost:  0.122012
# Epoch 91, Batch 4:  cost:  0.127394
# Epoch 91, Batch 5:  cost:  0.126634
# Epoch 91, Batch 6:  cost:  0.134764
# Epoch 91, Batch 7:  cost:  0.119666
# Epoch 95, Batch 17:  cost:  0.104748
# Epoch 95, Batch 18:  cost:  0.103789
# Epoch 95, Batch 19:  cost:  0.0981696
# Epoch 95, Batch 20:  cost:  0.0966507
# Epoch 95, Batch 21:  cost:  0.0912017
# Epoch 95, Batch 22:  cost:  0.0914101
# Epoch 95, Batch 23:  cost:  0.0981127
# Epoch 95, Batch 24:  cost:  0.102381
# Epoch 95, Batch 25:  cost:  0.107516
# Epoch 95, Batch 26:  cost:  0.10825
# Epoch 95, Batch 27:  cost:  0.117895
# Epoch 95, Batch 28:  cost:  0.12011
# Epoch 95, Batch 29:  cost:  0.118829
# Epoch 96, Batch 0:  cost:  0.138243
# Epoch 96, Batch 1:  cost:  0.123344
# Epoch 96, Batch 2:  cost:  0.11935
# Epoch 96, Batch 3:  cost:  0.116311
# Epoch 96, Batch 4:  cost:  0.122458
# Epoch 96, Batch 5:  cost:  0.125232
# Epoch 96, Batch 6:  cost:  0.133417
# Epoch 96, Batch 7:  cost:  0.121102
# Epoch 96, Batch 8:  cost:  0.118464
# Epoch 96, Batch 9:  cost:  0.124989
# Epoch 96, Batch 10:  cost:  0.11137
# Epoch 96, Batch 11:  cost:  0.104212
# Epoch 96, Batch 12:  cost:  0.0985248
# Epoch 96, Batch 13:  cost:  0.0991922
# Epoch 96, Batch 14:  cost:  0.106599
# Epoch 96, Batch 15:  cost:  0.104726
# Epoch 96, Batch 16:  cost:  0.100121
# Epoch 96, Batch 17:  cost:  0.103422
# Epoch 96, Batch 18:  cost:  0.103075
# Epoch 96, Batch 19:  cost:  0.099753
# Epoch 96, Batch 20:  cost:  0.101049
# Epoch 96, Batch 21:  cost:  0.0964097
# Epoch 96, Batch 22:  cost:  0.0946475
# Epoch 96, Batch 23:  cost:  0.100758
# Epoch 96, Batch 24:  cost:  0.10466
# Epoch 96, Batch 25:  cost:  0.107796
# Epoch 96, Batch 26:  cost:  0.108646
# Epoch 96, Batch 27:  cost:  0.117134
# Epoch 96, Batch 28:  cost:  0.115798
# Epoch 96, Batch 29:  cost:  0.113912
# Epoch 97, Batch 0:  cost:  0.128793
# Epoch 97, Batch 1:  cost:  0.117273
# Epoch 97, Batch 2:  cost:  0.113506
# Epoch 97, Batch 3:  cost:  0.110379
# Epoch 97, Batch 4:  cost:  0.119366
# Epoch 97, Batch 5:  cost:  0.120578
# Epoch 97, Batch 6:  cost:  0.12996
# Epoch 97, Batch 7:  cost:  0.118374
# Epoch 97, Batch 8:  cost:  0.119473
# Epoch 97, Batch 9:  cost:  0.125467
# Epoch 97, Batch 10:  cost:  0.111577
# Epoch 97, Batch 11:  cost:  0.107778
# Epoch 97, Batch 12:  cost:  0.100017
# Epoch 97, Batch 13:  cost:  0.103104
# Epoch 97, Batch 14:  cost:  0.106624
# Epoch 97, Batch 15:  cost:  0.102586
# Epoch 97, Batch 16:  cost:  0.094826
# Epoch 97, Batch 17:  cost:  0.0941575
# Epoch 97, Batch 18:  cost:  0.0930868
# Epoch 97, Batch 19:  cost:  0.0913846
# Epoch 97, Batch 20:  cost:  0.0920271
# Epoch 99, Batch 25:  cost:  0.0957493
# Epoch 99, Batch 26:  cost:  0.0975263
# Epoch 99, Batch 27:  cost:  0.107039
# Epoch 99, Batch 28:  cost:  0.106202
# Epoch 99, Batch 29:  cost:  0.1022
# Epoch 100, Batch 0:  cost:  0.121889
# Epoch 100, Batch 1:  cost:  0.113158
# Epoch 100, Batch 2:  cost:  0.11001
# Epoch 100, Batch 3:  cost:  0.107671
# Epoch 100, Batch 4:  cost:  0.110983
# Epoch 100, Batch 5:  cost:  0.112654
# Epoch 100, Batch 6:  cost:  0.119066
# Epoch 100, Batch 7:  cost:  0.107933
# Epoch 100, Batch 8:  cost:  0.109096
# Epoch 100, Batch 9:  cost:  0.114424
# Epoch 100, Batch 10:  cost:  0.101817
# Epoch 100, Batch 11:  cost:  0.0965466
# Epoch 100, Batch 12:  cost:  0.0902869
# Epoch 100, Batch 13:  cost:  0.0924814
# Epoch 100, Batch 14:  cost:  0.100222
# Epoch 100, Batch 15:  cost:  0.0970087
# Epoch 100, Batch 16:  cost:  0.0927884
# Epoch 100, Batch 17:  cost:  0.0923111
# Epoch 100, Batch 18:  cost:  0.0904525
# Epoch 100, Batch 19:  cost:  0.0910856
# Epoch 100, Batch 20:  cost:  0.0895365
# Epoch 100, Batch 21:  cost:  0.0826208
# Epoch 100, Batch 22:  cost:  0.0826287
# Epoch 100, Batch 23:  cost:  0.0892614
# Epoch 100, Batch 24:  cost:  0.0941417
# Epoch 100, Batch 25:  cost:  0.0964863
# Epoch 100, Batch 26:  cost:  0.0977212
# Epoch 100, Batch 27:  cost:  0.106374
# Epoch 100, Batch 28:  cost:  0.106134
# Epoch 100, Batch 29:  cost:  0.101507

# %% [markdown]
# ## Visualizing result
#
# Here I have tried to visualize the result. Above is the actual labeling done by a neuroscientist, underneath is the reconstruction of my model. Because there are no labels for the test set in the data, it is difficult to know whether the model overfits or not. You can leave some of the training samples out while training and compare the output they give after training the network and it still looks quit good. I'm no specialist in the field and have absolutely no idea whether this result is any good or if it is useful. I came up with the idea for this architecture myself but do not know if it already exist or anyone has come up with it way before me.

# %%
# Define input, label and output
x = 6
input_ = test_batches[x]
label_ = labels_batches[x]
reconstructed, compressed = sess.run([decoded, encoded], feed_dict={inputs: input_})

# %% [markdown]
# ### Input

# %%
plt.axis('off')
plt.imshow(input_.reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ### Label

# %%
plt.axis('off')
plt.imshow(label_.reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ### Output

# %%
plt.axis('off')
plt.imshow(reconstructed.reshape(512,512), cmap='Greys_r')

# %%
# Make list of all reconstructed images
all_reconstructed = []
for i in range(len(test_batches)):
    all_reconstructed.append(sess.run([decoded, encoded], feed_dict={inputs: volume_batches[i]})[0])

# %%
# Make it a ndarray and reshape
all_reconstructed = (np.asanyarray(all_reconstructed))
all_reconstructed = all_reconstructed.reshape(30, 512, 512, 1)

# %%
# Save the results in a 3D TIF file
io.imsave('Data/train-reconstructed.tif', all_reconstructed)

# %%
# Terminating the session
sess.close()
