# %% [markdown]
# # Convolutional Autoencoder for Neural Segmentation
#
# This is my implementation for the ISBI Challenge: Segmentation of neuronal structures in EM stacks. This is a challenge which can be found on the website of Dr. Seung's Lab at Princton http://seunglab.org/ or directly at http://brainiac2.mit.edu/isbi_challenge/ .
#
# ## The Challenge
#
# I will provide some information from the website about the challenge directly in this notebook. Please feel free to only read what seems important to you.
#
# ### Background and set-up
# In this challenge, a full stack of EM slices will be used to train machine learning algorithms for the purpose of automatic segmentation of neural structures. The images are representative of actual images in the real-world, containing some noise and small image alignment errors. None of these problems led to any difficulties in the manual labeling of each element in the image stack by an expert human neuroanatomist. The aim of the challenge is to compare and rank the different competing methods based on their pixel and object classification accuracy.
#
# ### Training data
# Training dataInput training data and corresponding labels.
# The training data is a set of 30 sections from a serial section Transmission Electron Microscopy (ssTEM) data set of the Drosophila first instar larva ventral nerve cord (VNC). The microcube measures 2 x 2 x 1.5 microns approx., with a resolution of 4x4x50 nm/pixel.
#
# The corresponding binary labels are provided in an in-out fashion, i.e. white for the pixels of segmented objects and black for the rest of pixels (which correspond mostly to membranes).
#
# To get the training data, please, register, log in and go to the "Downloads" section.
#
# This is the only data that participants are allowed to use to train their algorithms.
#
# ### Test data
# The contesting segmentation methods will be ranked by their performance on a test dataset, also available under "downloads", after registration. This test data is another volume from the same Drosophila first instar larva VNC as the training dataset.
#
# ### Results format
# The results are expected to be submitted as a 32-bit TIFF 3D image, which values between 0 (100% membrane certainty) and 1 (100% non-membrane certainty).

# %% [markdown]
# ## Data Preprocessing
#
# The data is read from three different .tif files and stored as numpy arrays. I needed to do some preprocessing before passing them to tensorflow. In particular, I've normalized the data, put it in batches and reshaped it so it could be passed to tensorflow.

# %%
# Import dependencies
from skimage import io
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load data
train_volume = io.imread('Data/train-volume.tif')
train_labels = io.imread('Data/train-labels.tif')
test_volume = io.imread('Data/test-volume.tif')

# %%
# Normalize function
def normalize(x):
    x = x.astype(np.float32)
    x /=255
    return x

# %%
# Normalize data
train_volume = normalize(train_volume)
train_labels = normalize(train_labels)
test_volume = normalize(test_volume)

# %%
# Batch function

# The data is currently a multidimensional numpy array (ndarray) with 3 dimensions. It has the shape 30 * 512 * 512, which
# means that the data exists of 30 greyscale pictures with dimension 512 pixels on 512 pixels. We want to make 30 batches of 1 
# picture each. We'll also have to reshape the data to pass it to convolutional layers in tensorflow (4 dimensions required).

def get_batches(data):
    data = np.reshape(data, (30, 512, 512, 1))
    data = np.split(data, 30)
    return data

# %%
# Batch data
volume_batches = get_batches(train_volume)
labels_batches = get_batches(train_labels)
test_batches = get_batches(test_volume)

# %% [markdown]
# ## Data visualisation
#
# Here I have plotted an example a of picture to train on and of a picture which will serve as a label. Here you can see nicely how a electron microscopy picutre was mapped by a neuroscientist. This takes a lot of time and it would be beneficial if we were able to automate it. To watch different pictures change the values of volume_batches[i] and labels_batches[i].

# %%
plt.axis('off')
plt.imshow(volume_batches[1].reshape(512,512), cmap='Greys_r')

# %%
plt.axis('off')
plt.imshow(labels_batches[1].reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ## Model
#
# Here I've constructed the actual convolutional autoencoder. Normally an autoencoder is used for data compression or denoising. The idea is that one neural net is the encoder and learns to map feautres of the data more efficiently. Then there is a second neural net, the decoder, which learns to map this compressed representation to data of the same resolution than the input data. If you try to minimalize the difference between the input and output, the two networks will optimize and become a relativly good data compression algorithm. When doing this with images you can use CNN because they typically perform better.
#
# I have modified this architecture a bit to fit to my needs. I have used a CNN as the 'encoder' layer and let the CNN learn important features for itself during the convolutions. Then I used a deconvolutional layer as the 'decoder', but instead of minimizing the difference between the input and the output, I have set up the loss as to minimize the difference between the output and the labels.
#
# I hope that by optimizing the neural nets this way, that the convolutional layer learns to decide which are the relevant features in the electron microscopy sample, and that the deconvolutional layer learns to map from this representation of useful features to a good approximation of the labeling of the neuroscientist.

# %%
# Construct a convolutional autoencoder

# Create placeholders
inputs = tf.placeholder(dtype = tf.float32, shape=(None, 512, 512, 1), name='inputs')
targets = tf.placeholder(dtype = tf.float32, shape=(None, 512, 512, 1), name='targets')
learning_rate = 0.001
dropout = 0.5

### Encoder
conv1 = tf.layers.conv2d(inputs, 32, 5, 1, padding='same', activation=tf.nn.relu)
# Now 512x512x32
maxpool1 = tf.layers.max_pooling2d(conv1, 2, 2, padding='same')
# Now 256x256x32
dropout1 = tf.layers.dropout(maxpool1, rate=dropout)
conv2 = tf.layers.conv2d(maxpool1, 64, 5, 1, padding='same', activation=tf.nn.relu)
# Now 256x256x64
maxpool2 = tf.layers.max_pooling2d(conv2, 2, 2, padding='same')
dropout2 = tf.layers.dropout(maxpool2, rate=dropout)
# Now 128x128x64
conv3 = tf.layers.conv2d(maxpool2, 128, 5, 1, padding='same', activation=tf.nn.relu)
# Now 128x128x128

encoded = tf.layers.max_pooling2d(conv3, 2, 2, padding='same')
# Now 64x64x128
dropout3 = tf.layers.dropout(encoded, rate=dropout)
    
### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (64,64))
# Now 64x64x128
conv5 = tf.layers.conv2d(upsample1, 128, 5, 1, padding='same', activation=tf.nn.relu)
# Now 64x64x128
dropout4 = tf.layers.dropout(conv5, rate=dropout)
upsample2 = tf.image.resize_nearest_neighbor(conv5, (128,128))
# Now 128x128x128
conv6 = tf.layers.conv2d(upsample2, 64, 5, 1, padding='same', activation=tf.nn.relu)
# Now 128x128x64
dropout5 = tf.layers.dropout(conv6, rate=dropout)
upsample3 = tf.image.resize_nearest_neighbor(conv6, (256,256))
# Now 256x256x64
conv7 = tf.layers.conv2d(upsample3, 32, 5, 1, padding='same', activation=tf.nn.relu)
# Now 256x256x32
dropout6 = tf.layers.dropout(conv7, rate=dropout)
upsample4 = tf.image.resize_nearest_neighbor(conv7, (512,512))
# Now 512x512x32
    
logits = tf.layers.conv2d(upsample4, 1, 5, 1, padding='same', activation=None)
# Now 512x512x1
dropout7 = tf.layers.dropout(logits, rate=dropout)
    
decoded = tf.sigmoid(dropout7, name='decoded')

# Loss and Optimizer
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits)
cost = tf.reduce_mean(loss)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training

# %%
## Function for training the Neural Network
def train_neural_network(session, optimizer, feature_batch, label_batch):
    session.run(optimizer, feed_dict = {inputs: feature_batch, targets: label_batch})

# Function for showing the stats
def print_stats(session, feature_batch, label_batch, cost):
    print("cost: ", session.run(cost, feed_dict = {inputs: feature_batch, targets: label_batch}))

# Hyperparameters
epochs = 10
batch_size = 1
          
### Train Model

saver = tf.train.Saver()

# Create the session
sess = tf.Session()

# Initializing the variables
sess.run(tf.global_variables_initializer())

# Training cycle
for epoch in range(epochs):
    n_batches = len(volume_batches)
    for i in range(0, n_batches):
        train_neural_network(sess, optimizer, volume_batches[i], labels_batches[i])
        print('Epoch {:>2}, Batch {}:  '.format(epoch + 1, i), end='')
        print_stats(sess, volume_batches[i], labels_batches[i], cost)
        
saver.save(sess, './checkpoints/generator.ckpt')
# Out:
# Epoch  1, Batch 0:  cost:  0.712469
# Epoch  1, Batch 1:  cost:  0.632071
# Epoch  1, Batch 2:  cost:  0.655511
# Epoch  1, Batch 3:  cost:  0.642744
# Epoch  1, Batch 4:  cost:  0.614327
# Epoch  1, Batch 5:  cost:  0.580365
# Epoch  1, Batch 6:  cost:  0.637694
# Epoch  1, Batch 7:  cost:  0.560653
# Epoch  1, Batch 8:  cost:  0.552861
# Epoch  1, Batch 9:  cost:  0.54216
# Epoch  1, Batch 10:  cost:  0.557015
# Epoch  1, Batch 11:  cost:  0.550426
# Epoch  1, Batch 12:  cost:  0.56518
# Epoch  1, Batch 13:  cost:  0.52343
# Epoch  1, Batch 14:  cost:  0.489045
# Epoch  1, Batch 15:  cost:  0.504636
# Epoch  1, Batch 16:  cost:  0.513688
# Epoch  1, Batch 17:  cost:  0.535959
# Epoch  1, Batch 18:  cost:  0.504397
# Epoch  1, Batch 19:  cost:  0.527631
# Epoch  1, Batch 20:  cost:  0.534672
# Epoch  1, Batch 21:  cost:  0.505847
# Epoch  1, Batch 22:  cost:  0.502872
# Epoch  1, Batch 23:  cost:  0.495456
# Epoch  1, Batch 24:  cost:  0.474075
# Epoch  1, Batch 25:  cost:  0.497956
# Epoch  1, Batch 26:  cost:  0.509239
# Epoch  1, Batch 27:  cost:  0.514892
# Epoch  1, Batch 28:  cost:  0.496632
# Epoch  1, Batch 29:  cost:  0.448638
# Epoch  2, Batch 0:  cost:  0.529942
# Epoch  2, Batch 1:  cost:  0.531991
# Epoch  2, Batch 2:  cost:  0.551745
# Epoch  2, Batch 3:  cost:  0.561184
# Epoch  2, Batch 4:  cost:  0.576402
# Epoch  2, Batch 5:  cost:  0.575038
# Epoch  2, Batch 6:  cost:  0.541525
# Epoch  2, Batch 7:  cost:  0.546625
# Epoch  2, Batch 8:  cost:  0.541064
# Epoch  2, Batch 9:  cost:  0.528218
# Epoch  2, Batch 10:  cost:  0.535489
# Epoch  2, Batch 11:  cost:  0.556214
# Epoch  2, Batch 12:  cost:  0.568902
# Epoch  2, Batch 13:  cost:  0.519859
# Epoch  2, Batch 14:  cost:  0.467081
# Epoch  2, Batch 15:  cost:  0.517426
# Epoch  2, Batch 16:  cost:  0.489819
# Epoch  2, Batch 17:  cost:  0.505272
# Epoch  2, Batch 18:  cost:  0.485666
# Epoch  2, Batch 19:  cost:  0.508229
# Epoch  2, Batch 20:  cost:  0.508821
# Epoch  2, Batch 21:  cost:  0.482978
# Epoch  2, Batch 22:  cost:  0.486652
# Epoch  2, Batch 23:  cost:  0.488045
# Epoch  2, Batch 24:  cost:  0.448838
# Epoch  2, Batch 25:  cost:  0.473356
# Epoch  2, Batch 26:  cost:  0.48806
# Epoch  2, Batch 27:  cost:  0.478393
# Epoch  2, Batch 28:  cost:  0.459766
# Epoch  2, Batch 29:  cost:  0.420804
# Epoch  3, Batch 0:  cost:  0.476117
# Epoch  3, Batch 1:  cost:  0.500533
# Epoch  3, Batch 2:  cost:  0.51967
# Epoch  3, Batch 3:  cost:  0.518564
# Epoch  3, Batch 4:  cost:  0.52534
# Epoch  3, Batch 5:  cost:  0.529181
# Epoch  3, Batch 6:  cost:  0.488285
# Epoch  3, Batch 7:  cost:  0.471696
# Epoch  3, Batch 8:  cost:  0.460094
# Epoch  3, Batch 9:  cost:  0.443371
# Epoch  3, Batch 10:  cost:  0.458137
# Epoch  3, Batch 11:  cost:  0.467447
# Epoch  3, Batch 12:  cost:  0.460486
# Epoch  3, Batch 13:  cost:  0.422883
# Epoch  3, Batch 14:  cost:  0.396675
# Epoch  3, Batch 15:  cost:  0.409391
# Epoch  3, Batch 16:  cost:  0.400162
# Epoch  3, Batch 17:  cost:  0.414363
# Epoch  3, Batch 18:  cost:  0.375557
# Epoch  3, Batch 19:  cost:  0.394199
# Epoch  3, Batch 20:  cost:  0.462463
# Epoch  3, Batch 21:  cost:  0.442142
# Epoch  3, Batch 22:  cost:  0.400391
# Epoch  3, Batch 23:  cost:  0.415726
# Epoch  3, Batch 24:  cost:  0.396935
# Epoch  3, Batch 25:  cost:  0.402413
# Epoch  3, Batch 26:  cost:  0.427193
# Epoch  3, Batch 27:  cost:  0.451747
# Epoch  3, Batch 28:  cost:  0.455866
# Epoch  3, Batch 29:  cost:  0.401071
# Epoch  4, Batch 0:  cost:  0.411883
# Epoch  4, Batch 1:  cost:  0.41586
# Epoch  4, Batch 2:  cost:  0.450209
# Epoch  4, Batch 3:  cost:  0.423798
# Epoch  4, Batch 4:  cost:  0.454734
# Epoch  4, Batch 5:  cost:  0.448833
# Epoch  4, Batch 6:  cost:  0.432561
# Epoch  4, Batch 7:  cost:  0.420254
# Epoch  4, Batch 8:  cost:  0.407591
# Epoch  4, Batch 9:  cost:  0.380107
# Epoch  4, Batch 10:  cost:  0.399209
# Epoch  4, Batch 11:  cost:  0.38956
# Epoch  4, Batch 12:  cost:  0.387966
# Epoch  4, Batch 13:  cost:  0.345265
# Epoch  4, Batch 14:  cost:  0.322468
# Epoch  4, Batch 15:  cost:  0.325089
# Epoch  4, Batch 16:  cost:  0.328855
# Epoch  4, Batch 17:  cost:  0.343863
# Epoch  4, Batch 18:  cost:  0.307704
# Epoch  4, Batch 19:  cost:  0.3219
# Epoch  4, Batch 20:  cost:  0.375984
# Epoch  4, Batch 21:  cost:  0.324297
# Epoch  4, Batch 22:  cost:  0.316572
# Epoch  4, Batch 23:  cost:  0.41456
# Epoch  4, Batch 24:  cost:  0.308917
# Epoch  4, Batch 25:  cost:  0.358454
# Epoch  4, Batch 26:  cost:  0.402666
# Epoch  4, Batch 27:  cost:  0.418702
# Epoch  4, Batch 28:  cost:  0.399148
# Epoch  4, Batch 29:  cost:  0.352752
# Epoch  5, Batch 0:  cost:  0.382547
# Epoch  5, Batch 1:  cost:  0.369604
# Epoch  5, Batch 2:  cost:  0.370623
# Epoch  5, Batch 3:  cost:  0.352488
# Epoch  5, Batch 4:  cost:  0.407585
# Epoch  5, Batch 5:  cost:  0.398112
# Epoch  5, Batch 6:  cost:  0.36269
# Epoch  5, Batch 7:  cost:  0.361232
# Epoch  5, Batch 8:  cost:  0.349939
# Epoch  5, Batch 9:  cost:  0.343643
# Epoch  5, Batch 10:  cost:  0.334491
# Epoch  5, Batch 11:  cost:  0.363571
# Epoch  5, Batch 12:  cost:  0.362497
# Epoch  5, Batch 13:  cost:  0.334774
# Epoch  5, Batch 14:  cost:  0.309702
# Epoch  5, Batch 15:  cost:  0.310644
# Epoch  5, Batch 16:  cost:  0.310172
# Epoch  5, Batch 17:  cost:  0.328261
# Epoch  5, Batch 18:  cost:  0.294222
# Epoch  5, Batch 19:  cost:  0.308055
# Epoch  5, Batch 20:  cost:  0.337539
# Epoch  5, Batch 21:  cost:  0.312742
# Epoch  5, Batch 22:  cost:  0.327383
# Epoch  5, Batch 23:  cost:  0.307867
# Epoch  5, Batch 24:  cost:  0.28453
# Epoch  5, Batch 25:  cost:  0.334195
# Epoch  5, Batch 26:  cost:  0.32136
# Epoch  5, Batch 27:  cost:  0.315521
# Epoch  5, Batch 28:  cost:  0.316501
# Epoch  5, Batch 29:  cost:  0.280053
# Epoch  6, Batch 0:  cost:  0.320122
# Epoch  6, Batch 1:  cost:  0.310623
# Epoch  6, Batch 2:  cost:  0.316172
# Epoch  6, Batch 3:  cost:  0.308342
# Epoch  6, Batch 4:  cost:  0.366024
# Epoch  6, Batch 5:  cost:  0.360664
# Epoch  6, Batch 6:  cost:  0.331098
# Epoch  6, Batch 7:  cost:  0.32399
# Epoch  6, Batch 8:  cost:  0.30165
# Epoch  6, Batch 9:  cost:  0.311654
# Epoch  6, Batch 10:  cost:  0.285791
# Epoch  6, Batch 11:  cost:  0.338416
# Epoch  6, Batch 12:  cost:  0.351012
# Epoch  6, Batch 13:  cost:  0.319337
# Epoch  6, Batch 14:  cost:  0.278015
# Epoch  6, Batch 15:  cost:  0.280538
# Epoch  6, Batch 16:  cost:  0.295026
# Epoch  6, Batch 17:  cost:  0.327994
# Epoch  6, Batch 18:  cost:  0.287428
# Epoch  6, Batch 19:  cost:  0.300112
# Epoch  6, Batch 20:  cost:  0.340656
# Epoch  6, Batch 21:  cost:  0.278222
# Epoch  6, Batch 22:  cost:  0.312217
# Epoch  6, Batch 23:  cost:  0.320719
# Epoch  6, Batch 24:  cost:  0.309705
# Epoch  6, Batch 25:  cost:  0.300397
# Epoch  6, Batch 26:  cost:  0.292779
# Epoch  6, Batch 27:  cost:  0.305057
# Epoch  6, Batch 28:  cost:  0.285404
# Epoch  6, Batch 29:  cost:  0.253
# Epoch  7, Batch 0:  cost:  0.322262
# Epoch  7, Batch 1:  cost:  0.30018
# Epoch  7, Batch 2:  cost:  0.306658
# Epoch  7, Batch 3:  cost:  0.294356
# Epoch  7, Batch 4:  cost:  0.350335
# Epoch  7, Batch 5:  cost:  0.359037
# Epoch  7, Batch 6:  cost:  0.328048
# Epoch  7, Batch 7:  cost:  0.31731
# Epoch  7, Batch 8:  cost:  0.302176
# Epoch  7, Batch 9:  cost:  0.292155
# Epoch  7, Batch 10:  cost:  0.296214
# Epoch  7, Batch 11:  cost:  0.277321
# Epoch  7, Batch 12:  cost:  0.296568
# Epoch  7, Batch 13:  cost:  0.265633
# Epoch  7, Batch 14:  cost:  0.243481
# Epoch  7, Batch 15:  cost:  0.238682
# Epoch  7, Batch 16:  cost:  0.249809
# Epoch  7, Batch 17:  cost:  0.259077
# Epoch  7, Batch 18:  cost:  0.238363
# Epoch  7, Batch 19:  cost:  0.248163
# Epoch  7, Batch 20:  cost:  0.287402
# Epoch  7, Batch 21:  cost:  0.252919
# Epoch  7, Batch 22:  cost:  0.289541
# Epoch  7, Batch 23:  cost:  0.278691
# Epoch  7, Batch 24:  cost:  0.273417
# Epoch  7, Batch 25:  cost:  0.258495
# Epoch  7, Batch 26:  cost:  0.256868
# Epoch  7, Batch 27:  cost:  0.273053
# Epoch  7, Batch 28:  cost:  0.257244
# Epoch  7, Batch 29:  cost:  0.237334
# Epoch  8, Batch 0:  cost:  0.299194
# Epoch  8, Batch 1:  cost:  0.272727
# Epoch  8, Batch 2:  cost:  0.278058
# Epoch  8, Batch 3:  cost:  0.281309
# Epoch  8, Batch 4:  cost:  0.324791
# Epoch  8, Batch 5:  cost:  0.334884
# Epoch  8, Batch 6:  cost:  0.298371
# Epoch  8, Batch 7:  cost:  0.295062
# Epoch  8, Batch 8:  cost:  0.278731
# Epoch  8, Batch 9:  cost:  0.264453
# Epoch  8, Batch 10:  cost:  0.249984
# Epoch  8, Batch 11:  cost:  0.264875
# Epoch  8, Batch 12:  cost:  0.285409
# Epoch  8, Batch 13:  cost:  0.249077
# Epoch  8, Batch 14:  cost:  0.214699
# Epoch  8, Batch 15:  cost:  0.228956
# Epoch  8, Batch 16:  cost:  0.220052
# Epoch  8, Batch 17:  cost:  0.25034
# Epoch  8, Batch 18:  cost:  0.237931
# Epoch  8, Batch 19:  cost:  0.243757
# Epoch  8, Batch 20:  cost:  0.286716
# Epoch  8, Batch 21:  cost:  0.256096
# Epoch  8, Batch 22:  cost:  0.258182
# Epoch  8, Batch 23:  cost:  0.244993
# Epoch  8, Batch 24:  cost:  0.253214
# Epoch  8, Batch 25:  cost:  0.250876
# Epoch  8, Batch 26:  cost:  0.248631
# Epoch  8, Batch 27:  cost:  0.266018
# Epoch  8, Batch 28:  cost:  0.264324
# Epoch  8, Batch 29:  cost:  0.238739
# Epoch  9, Batch 0:  cost:  0.268233
# Epoch  9, Batch 1:  cost:  0.258072
# Epoch  9, Batch 2:  cost:  0.272814
# Epoch  9, Batch 3:  cost:  0.258672
# Epoch  9, Batch 4:  cost:  0.307094
# Epoch  9, Batch 5:  cost:  0.321839
# Epoch  9, Batch 6:  cost:  0.285588
# Epoch  9, Batch 7:  cost:  0.282751
# Epoch  9, Batch 8:  cost:  0.265868
# Epoch  9, Batch 9:  cost:  0.265812
# Epoch  9, Batch 10:  cost:  0.253613
# Epoch  9, Batch 11:  cost:  0.254067
# Epoch  9, Batch 12:  cost:  0.278672
# Epoch  9, Batch 13:  cost:  0.259736
# Epoch  9, Batch 14:  cost:  0.220668
# Epoch  9, Batch 15:  cost:  0.227601
# Epoch  9, Batch 16:  cost:  0.224416
# Epoch  9, Batch 17:  cost:  0.250596
# Epoch  9, Batch 18:  cost:  0.230757
# Epoch  9, Batch 19:  cost:  0.234593
# Epoch  9, Batch 20:  cost:  0.27376
# Epoch  9, Batch 21:  cost:  0.231867
# Epoch  9, Batch 22:  cost:  0.25458
# Epoch  9, Batch 23:  cost:  0.242836
# Epoch  9, Batch 24:  cost:  0.238351
# Epoch  9, Batch 25:  cost:  0.234673
# Epoch  9, Batch 26:  cost:  0.234032
# Epoch  9, Batch 27:  cost:  0.255067
# Epoch  9, Batch 28:  cost:  0.241406
# Epoch  9, Batch 29:  cost:  0.22999
# Epoch 10, Batch 0:  cost:  0.272962
# Epoch 10, Batch 1:  cost:  0.250207
# Epoch 10, Batch 2:  cost:  0.257439
# Epoch 10, Batch 3:  cost:  0.247383
# Epoch 10, Batch 4:  cost:  0.29474
# Epoch 10, Batch 5:  cost:  0.31446
# Epoch 10, Batch 6:  cost:  0.280891
# Epoch 10, Batch 7:  cost:  0.272181
# Epoch 10, Batch 8:  cost:  0.258669
# Epoch 10, Batch 9:  cost:  0.24204
# Epoch 10, Batch 10:  cost:  0.237553
# Epoch 10, Batch 11:  cost:  0.229312
# Epoch 10, Batch 12:  cost:  0.252844
# Epoch 10, Batch 13:  cost:  0.231866
# Epoch 10, Batch 14:  cost:  0.194227
# Epoch 10, Batch 15:  cost:  0.19951
# Epoch 10, Batch 16:  cost:  0.201028
# Epoch 10, Batch 17:  cost:  0.219237
# Epoch 10, Batch 18:  cost:  0.203436
# Epoch 10, Batch 19:  cost:  0.214175
# Epoch 10, Batch 20:  cost:  0.251249
# Epoch 10, Batch 21:  cost:  0.223177
# Epoch 10, Batch 22:  cost:  0.217061
# Epoch 10, Batch 23:  cost:  0.214535
# Epoch 10, Batch 24:  cost:  0.221924
# Epoch 10, Batch 25:  cost:  0.235748
# Epoch 10, Batch 26:  cost:  0.228259
# Epoch 10, Batch 27:  cost:  0.242754
# Epoch 10, Batch 28:  cost:  0.223493
# Epoch 10, Batch 29:  cost:  0.220985
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-4c42f4d0b83f> in <module>()
#      29         print_stats(sess, volume_batches[i], labels_batches[i], cost)
#      30
# ---> 31 saver.save(sess, 'Data')
#
# C:\Users\Anton\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1363     if not gfile.IsDirectory(os.path.dirname(save_path)):
#    1364       raise ValueError(
# -> 1365           "Parent directory of {} doesn't exist, can't save.".format(save_path))
#    1366
#    1367     save_path = os.path.dirname(save_path)
#
# ValueError: Parent directory of Data doesn't exist, can't save.

# %% [markdown]
# ## Visualizing result
#
# Here I have tried to visualize the result. Above is the actual labeling done by a neuroscientist, underneath is the reconstruction of my model. Because there are no labels for the test set in the data, it is difficult to know whether the model overfits or not. You can leave some of the training samples out while training and compare the output they give after training the network and it still looks quit good. I'm no specialist in the field and have absolutely no idea whether this result is any good or if it is useful. I came up with the idea for this architecture myself but do not know if it already exist or anyone has come up with it way before me.

# %%
# Define input, label and output
x = 6
input_ = test_batches[x]
label_ = labels_batches[x]
reconstructed, compressed = sess.run([decoded, encoded], feed_dict={inputs: input_})

# %% [markdown]
# ### Input

# %%
plt.axis('off')
plt.imshow(input_.reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ### Label

# %%
plt.axis('off')
plt.imshow(label_.reshape(512,512), cmap='Greys_r')

# %% [markdown]
# ### Output

# %%
plt.axis('off')
plt.imshow(reconstructed.reshape(512,512), cmap='Greys_r')

# %%
# Make list of all reconstructed images
all_reconstructed = []
for i in range(len(test_batches)):
    all_reconstructed.append(sess.run([decoded, encoded], feed_dict={inputs: volume_batches[i]})[0])

# %%
# Make it a ndarray and reshape
all_reconstructed = (np.asanyarray(all_reconstructed))
all_reconstructed = all_reconstructed.reshape(30, 512, 512, 1)

# %%
# Save the results in a 3D TIF file
io.imsave('Data/train-reconstructed.tif', all_reconstructed)

# %%
# Terminating the session
sess.close()
